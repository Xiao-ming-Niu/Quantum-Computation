# %% [markdown]
# # Grover 算法实现
# ----

# %%
# 导入所需库并检查 unitarylab 库是否可用
import unitarylab
import unitarylab_algorithms

print(unitarylab.__version__)
print(unitarylab_algorithms.__version__)
# Out:
# 1.1.5
# 1.1.6
